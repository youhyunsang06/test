# %% [markdown]
# # 1. 변수

# %% [markdown]
# 변수는 프로그램에서 데이터를 저장하기 위해 사용하는 이름으로, 메모리에 저장된 값을 참조하는 역할을 합니다. 값을 직접 다루는 대신 변수 이름을 통해 데이터를 읽고 변경할 수 있으며, 프로그램 실행 중에 값이 변할 수 있다는 특징을 가집니다. 이를 통해 데이터를 효율적으로 관리하고 재사용할 수 있습니다.

# %% [markdown]
# ```
# a = "memory"
#
# ```

# %% [markdown]
# ### 1.1  Python의 변수 동작 방식

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# - 👉 10이라는 객체를 메모리(힙)에 생성
#
# - 👉 x는 그 객체를 “참조(reference)”함
#
#     - 변수 = 값이 아니라 “객체를 가리키는 이름”
#     숫자, 문자열, 리스트 등 모든 객체는 힙(Heap)에 저장됨
#     - 변수 (이름)은 객체를 가리키는 참조이며 내부적으로는 네임스페이스(딕셔너리 구조)에 저장됨

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'x = 10\nprint(x)', 'print(globals())'], '_oh': {}, '_dh': [WindowsPath('c:/Python/1_Python')], 'In': ['', 'x = 10\nprint(x)', 'print(globals())'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001CBA065EE10>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x000001CBA06740D0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x000001CBA06740D0>, 'open': <function open at 0x000001CB9E671080>, '_': '', '__': '', '___': '', '__vsc_ipynb_file__': 'c:\\Python\\1_Python\\1_파이썬변수.ipynb', '_i': 'x = 10\nprint(x)', '_ii': '', '_iii': '', '_i1': 'x = 10\nprint(x)', 'x': 10, '_i2': 'print(globals())'}

# %% [markdown]
# ### globals()
# globals()는 현재 실행 중인 모듈의 전역 네임스페이스를 나타내는 딕셔너리를 반환하는 내장 함수로, 전역 범위에 정의된 변수, 함수, 클래스 등의 이름과 해당 객체 간의 매핑 정보를 확인할 수 있게 해줍니다. 이 딕셔너리를 통해 전역 변수에 접근하거나 값을 조회·수정할 수 있으며, Python에서 변수 이름이 실제로는 네임스페이스(dict)에 저장되어 관리된다는 구조를 이해하는 데 중요한 역할을 합니다.

# %%
name = "김사과"
age = 20

print(name)
print(age)
# Out:
# 김사과
# 20

# %%
name = "바나나"
print(name)
# Out:
# 바나나

# %%
a = 200
b = 200
print(a)
print(b)
# Out:
# 200
# 200

# %%
print(a is b) # is는 a와 b가 같은 값인지 비교연산자
# Out:
# True

# %%
print(id(a))
print(id(b))
# Out:
# 140708281015304
# 140708281015304

# %% [markdown]
# ### 1.2 변수 이름 작성하는 방법

# %% [markdown]
# 1. 변수 이름은 알파벳(대문자 또는 소문자), 숫자, 밑줄(_)로 구성될 수 있습니다.
# 2. 숫자로 시작할 수 없습니다.
# 3. 공백을 포함할 수 없습니다. 대신 밑줄(_)을 사용할 수 있습니다
# 4. 파이썬의 예약어(키워드)는 변수 이름으로 사용할 수 없습니다. 예약어는 if, for, class, def 등 파이썬이 이미 사용하는 특별한 단어들입니다.

# %% [markdown]
# # 2. 자료형

# %% [markdown]
# 파이썬의 자료형은 데이터를 저장하고 처리하기 위한 값의 종류를 말합니다. 어떤 값이 무엇인지(숫자인지, 문자인지, 목록인지 등) 파악하고 처리하는 기준입니다. 파이썬은 동적 타입 언어이기 때문에, 변수에 어떤 값을 넣느냐에 따라 자동으로 자료형이 결정됩니다.

# %% [markdown]
# ### 2.1 기본 자료형

# %% [markdown]
# 숫자형 (Number)
#
# - 정수형(int): 소수점 없는 숫자 → 10, -3, 0
# - 실수형(float): 소수점 있는 숫자 → 3.14, -0.5

# %% [markdown]
# 문자열형 (str)
#
# - 글자들의 집합 (문자열) → "hello", '파이썬'
# - 큰따옴표(")나 작은따옴표(') 둘 다 사용 가능

# %% [markdown]
# 불린형 (bool)
#
# - 참(True) 또는 거짓(False) 값을 가짐
# - 조건문 등에 많이 사용

# %%
name = '김사과'
age = 20 
weight = 50.5
isLover = False

print(name)
print(age)
print(weight)
print(isLover)

print(type(name))
print(type(age))
print(type(weight))
print(type(isLover))
# Out:
# 김사과
# 20
# 50.5
# False
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ### 2.2 집합형 자료형
#
# 리스트 (list)
# - 여러 값을 순서대로 저장할 수 있는 자료형 → [] 사용
# - 값의 중복 허용, 수정 가능

# %% [markdown]
# 튜플 (tuple)
#
# - 리스트처럼 여러 값을 저장하지만 수정 불가능 → () 사용
# - 예: (1, 2, 3)

# %% [markdown]
# 딕셔너리 (dict)
#
# - 키(key)와 값(value)의 쌍으로 저장 → {} 사용
# - 순서 보장 (Python 3.7+), 키는 중복 불가

# %% [markdown]
# 집합 (set)
#
# - 중복 없는 값들의 모음 → {} 또는 set() 사용
# - 순서 없음, 인덱싱 불가

# %% [markdown]
# # 3. 자료형 변환

# %% [markdown]
# 자료형 변환(Type Casting)은 하나의 데이터 타입을 다른 타입으로 바꾸는 것을 의미하며, 데이터의 형태를 상황에 맞게 맞추기 위해 사용됩니다.

# %%
j = 3.14
k = str(j)
print(type(k))
# Out:
# <class 'str'>

# %% [markdown]
# # 4. 변수 삭제하기

# %% [markdown]
# 변수를 삭제하기 위해 del 문을 사용할 수 있습니다. del 문은 지정된 변수를 제거하고 해당 메모리 공간을 해제합니다. 변수가 삭제되면 해당 이름으로 변수에 더 이상 접근할 수 없습니다. 주의해야 할 점은 del 문을 사용하여 변수를 삭제할 때 해당 변수에 연결된 메모리가 해제되지만, 변수가 참조하던 값 자체는 삭제되지 않습니다.

# %%
name1 = '김사과'
name2 = name1

del name1

print(name2)

# %% [markdown]
# 가비지 컬렉션(Garbage Collection)
# 파이썬에서는 변수나 객체를 만들면, 그 값은 메모리의 힙(heap) 영역에 저장됩니다. 하지만 프로그램을 계속 실행하면서 더 이상 사용하지 않는 객체들이 쌓이면 메모리 낭비가 생기게 됩니다. 이때 가비지 컬렉터(GC)가 작동하여, 쓸모없는 객체를 찾아서 자동으로 메모리에서 제거해줍니다.
