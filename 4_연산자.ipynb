# %% [markdown]
# 연산자는 값을 계산하거나 비교하고, 논리적인 판단을 수행하기 위해 사용하는 기호로, 데이터 간의 연산을 간결하게 표현할 수 있게 해줍니다.

# %% [markdown]
# # 1. 산술 연산자

# %% [markdown]
#  산술 연산자는 주로 수치 데이터 유형에 대한 기본 산술 연산을 수행하기 위해 사용됩니다.
#
# ```
# + : 더하기
# - : 빼기
# * : 곱하기
# / : 나누기
# //: 몫 (정수 나누기)
# % : 나머지
# **: 지수 (거듭제곱)
# ```

# %%
print(10 + 3)
print(10 - 3)
print(10 * 3)
print(10 / 3) # 파이썬의 나누기는 무조건 실수(소수점)
print(10 // 3)
print(10 % 3)
print(10 ** 3)

# %% [markdown]
# # 2. 비교 연산자
# 비교 연산자는 주로 두 값을 비교하는 데 사용되며, 그 결과는 항상 불리언(True 또는 False) 값입니다.

# %% [markdown]
# ```
# ==: 동등
# !=: 동등하지 않음
# < : 작다
# <=: 작거나 같다
# > : 크다
# >=: 크거나 같다
# ```

# %%
print(10 > 5)
print(10 < 5)
print(10 >= 5)
print(10 <= 5)
print(10 == 5)
print(10 != 5)
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# # 3. 할당 연산자
# 변수에 값을 할당하는데 사용됩니다. 파이썬에서는 기본 할당 연산자 외에도 복합 할당 연산자를 제공하여 코드를 간결하게 작성할 수 있게 도와줍니다.

# %% [markdown]
# ```
# = : 할당
# += : 더하기 후 할당
# -= : 빼기 후 할당
# *= : 곱하기 후 할당
# /= : 나누기 후 할당
# //=: 몫 후 할당
# %= : 나머지 후 할당
# **=: 지수 후 할당
#
# ```

# %%
num = 10
num += 1 # num = num + 1
print(num)
num -= 1
print(num)
num *= 10
print(num)
num /=10
print(num)  # 정수로 나누어 떨어져도 자료형이 실수형이 된다!.
num %= 2
print(num)  # 실수와 자연수 연산은 무조건 실수가 나옴
# Out:
# 11
# 10
# 100
# 10.0
# 0.0

# %% [markdown]
# # 4. 비트 연산자
# 비트 연산자는 정수를 이진 비트로 표현했을 때 사용하는 연산자들입니다. 각 연산자는 정수의 비트 단위로 동작합니다

# %% [markdown]
# ```
# & : 비트 단위 AND - 모두 1일때 1, 그 외에 0
# | : 비트 단위 OR - 둘 중에 하나 1일때 1, 그 외에 0
# ^ : 비트 단위 XOR - 둘이 서로 다를 때 1, 그 외에 0
# ~ : 비트 단위 NOT
# << : 왼쪽 시프트
# >> : 오른쪽 시프트
#
# ```

# %%
a = 60
b = 13
print (a & b)
print (a | b)
print (a ^ b)
print (~a)
# Out:
# 12
# 61
# 49
# -61

# %% [markdown]
# ### 컴퓨터에서 음수를 표현하는 방법
# 컴퓨터는 0과 1로만 데이터를 표현하기 때문에 음수를 직접 표현할 수 없으며, 이를 해결하기 위해 2의 보수(2’s complement) 방식을 사용합니다. 2의 보수는 양수의 이진수를 비트 반전(0↔1)한 후 1을 더하는 방식으로 음수를 표현하는 방법으로, 예를 들어 5(00000101)를 음수로 만들면 비트를 뒤집어 11111010을 만든 뒤 1을 더해 11111011이 되어 -5를 나타냅니다. 이 방식은 0을 하나로 유지할 수 있고, 덧셈만으로 뺄셈을 처리할 수 있어 컴퓨터에서 효율적으로 사용됩니다.

# %% [markdown]
# # 5. 논리 연산자
# 파이썬에서의 논리 연산자는 주로 불린(Boolean) 값을 조작하기 위해 사용됩니다. 그러나 파이썬의 논리 연산자는 다른 언어와는 다르게, 연산의 결과로 항상 True 또는 False만을 반환하는 것은 아닙니다. 대신 마지막으로 평가된 피연산자의 값을 반환합니다.

# %% [markdown]
# ```
# and: 논리 AND
# or : 논리 OR
# not: 논리 NOT
# ```

# %%
a = True
b = False

# AND 연산 (둘 다 True일 때 True)
print(a and b)

# OR 연산 (하나라도 True일 대 True)
print(a or b )

# NOT 연산 (값을 반대로)
print(not a)
print(not b)
# Out:
# False
# True
# False
# True

# %%
# and
print(True and 3) # 앞이 True이고 and 이기 때문에 뒤에 값만 보면 됨
print(3 and 5) # 3, 5 모두 값이 True 이기 때문에 뒤에 값이 나옴
print(0 and 5) # 0은 false이기 때문에 뒤에 값을 안봐도 됨
# Out:
# 3
# 5
# 0

# %%
#or
print (False or 3)
print (3 or 5) # 앞에 값이 True면 뒤에 값이 True, False 상관없음. 뒤에 값 신경 안씀.
print (0 or 5) # 앞에 값이 False 이기 때문에 뒤에 값이 나옴
# Out:
# 3
# 3

# %%
#not
print(not True)
print(not 0)
print(not 3) # 3은 True 값이므로
# Out:
# False
# True
# False

# %% [markdown]
# # 6. 파이썬에서 불린(Boolean)으로 평가되는 주요 값

# %% [markdown]
# ### 1. True로 평가되는 주요 값
#
# - 0이 아닌 모든 숫자 (양수, 음수 모두 포함)
#
# - 비어 있지 않은 문자열, 비어 있지 않은 리스트, 비어 있지 않은 튜플, 비어 있지 않은 세트, 비어 있지 않은 딕셔너리
#
# - True

# %% [markdown]
# ### 2. False로 평가되는 주요 값
# - False
#
# - 0
#
# - 빈 문자열 빈 리스트 [], 빈 튜플 (), 빈 세트 set(), 빈 딕셔너리 {}
#
# - None
